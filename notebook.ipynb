# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
video_df = pd.read_csv('/home/micasidad/Desktop/yt-comment-analysis/data/unpreprocessed/videos_metadata.csv', encoding='utf-8')
comment_df =pd.read_csv('/home/micasidad/Desktop/yt-comment-analysis/data/unpreprocessed/comments_metadata.csv', encoding='utf-8')

# %%
video_df
# Out:
#              ID                                              TITLE  \
# 0   WgKqz-xjUCg  Con Đường Mưa || St: Nguyễn Văn Chung || Guita...
# 1   6pPxy713RhI     Hoa Hải Đường | Jack | Cover Guitar đệm hợp âm
# 2   fpDN6pfCwHA  Giấc Mơ Tình Yêu - Hương Lê | Guitar Cover | A...
# 3   B6g5_PyrXNw  Đúng Cũng Thành Sai | Mỹ Tâm | Guitar cover có...
# 4   AAEX3Iqqmu4  Happy For You - Lukas Graham (feat. Vũ.)  || C...
# 5   m-L5Ies18RM  Đi Cùng Em - Hà Tròn ft. Lemon Climb || Cover ...
# 6   kbaQDZEvXLs    Vợ ơi | Lê Bảo Bình | Guitar cover chỉ 4 hợp âm
# 7   IM4lor3o96I  NGHE - NÓI || OBITO & PJPO || RAP VIỆT MÙA 2 C...
# 8   O-Nz2ltbZLY  Yêu Thầm | Hoàng Yến Chibi x Tlinh x Lyly x TD...
# 9   xEkkQ5Jjl7M  Trốn Tìm - Đen Vâu ft. MTV band || Cover guita...
# 10  C2baIpyFBZA   LAYLALAY (ANH ĐÃ SAI) | JACK | Guitar đệm hợp âm
# 11  NSXtHFlwEAw  Sao Cha Không || Phạn Mạnh Quỳnh || Nhạc phim ...
# 12  kzbupW6wjVo  What Love Is...ba chàng ngông team Binz với 3 ...
# ...

# %%
with open('instruction.txt', 'w') as f:
    # Iterate over each row in the DataFrame
    for row in video_df.itertuples(index=False, name=None):
        # Write the SQL statement to the file
        f.write(f"INSERT INTO RAW_VIDEOS VALUES" + str(row) + ";\n")

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            52 non-null     object
#  1   title         52 non-null     object
#  2   description   50 non-null     object
#  3   publishedAt   52 non-null     object
#  4   categoryId    52 non-null     int64
#  5   duration      52 non-null     object
#  6   caption       52 non-null     bool
#  7   likeCount     52 non-null     int64
#  8   commentCount  52 non-null     int64
#  9   viewCount     52 non-null     int64
# dtypes: bool(1), int64(4), object(5)
# memory usage: 3.8+ KB

# %%
comment_df[comment_df['AUTHOR'] == '@dungbebongchanel5266']
# Out:
#      REPLY_COUNT                 AUTHOR  \
# 139            0  @dungbebongchanel5266
#
#                                                   TEXT  LIKE_COUNT  \
# 139  ướt ở trên mi mỗi lần qua từng nơi dấu chân ta...           0
#
#              PUBLISHED_AT     VIDEO_ID
# 139  2024-04-02T13:25:54Z  LkaccexMhFQ
